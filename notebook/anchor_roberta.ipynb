# %%
# ray Roberta anchorD:\Universidad\informatica 4 año\2do Semestre\tesis_XAI
from explainability_techniques.anchor import AnchorExplainer
from transformers import AutoTokenizer
from models.roberta_model import load_roberta_model_notebook
import torch
import pickle
import pandas as pd
from utils.utils import load_dataset, save_explanation, predict_relevance_comment
import sys
sys.path.append(
    'D:/Universidad/informatica 4 año/2do Semestre/tesis_XAI')
# Verificar si hay una GPU disponible
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
devNumber = torch.cuda.current_device()
print(f"Current divice number is: {devNumber}")
devName = torch.cuda.get_device_name(devNumber)
print(f"GPU name is: {devNumber}")
# Out:
# Using device: cpu
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 15
#      13 device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#      14 print(f"Using device: {device}")
# ---> 15 devNumber=torch.cuda.current_device()
#      16 print(f"Current divice number is: {devNumber}")
#      17 devName=torch.cuda.get_device_name(devNumber)
#
# File c:\Users\naybv\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\cuda\__init__.py:940, in current_device()
#     938 def current_device() -> int:
#     939     r"""Return the index of a currently selected device."""
# --> 940     _lazy_init()
#     941     return torch._C._cuda_getDevice()
#
# File c:\Users\naybv\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\cuda\__init__.py:310, in _lazy_init()
#     305     raise RuntimeError(
# ...

# %%
dataset = pd.read_csv(
    "../models/relevance_classification/dataset/facebook_labeled.csv", sep=",")

# %%
roberta_model = load_roberta_model_notebook()

tokenizer = AutoTokenizer.from_pretrained("roberta-base")
# Out:
# D:\Universidad/informatica 4 año/2do Semestre/tesis_XAI\models\roberta_model.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(
# ...

# %%
# Crear el explicador de Anchors
anchor_explainer = AnchorExplainer(class_names=['not relevant', 'relevant'])

# %%
# Seleccionar una instancia para explicar
print(len(dataset['Review']))

instance = dataset['Review'].iloc[105]
print(instance)
# Out:
# 3000
# please add the option to save photo like in ios...

# %%
def predict_relevance(instance):
    # if isinstance(instance, list):
    #     print("entraaaaaa")
    #     instance = instance[0]  # Extraer el primer elemento si es una lista
    return predict_relevance_comment(instance, roberta_model, tokenizer)

# %%
# Explicar la instancia
exp = anchor_explainer.explain_instance(
    instance, predict_relevance, threshold=0.95)
# Out:
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Explicar la instancia
# ----> 2 exp = anchor_explainer.explain_instance(
#       3     instance, predict_relevance, threshold=0.95)
#
# File D:\Universidad/informatica 4 año/2do Semestre/tesis_XAI\explainability_techniques\anchor.py:14, in AnchorExplainer.explain_instance(self, instance, predict_function, threshold)
#      13 def explain_instance(self, instance, predict_function, threshold=0.95):
# ---> 14     return self.explainer.explain_instance(
#      15         instance,
#      16         predict_function,
#      17         threshold=threshold
#      18     )
#
# ...

# %%
# print(dir(exp))
# Guardar y abrir el HTML
html_roberta = exp.as_html()
save_explanation(html_roberta, 'roberta_explanation_opinion105_anchor.html')
anchor_explainer.save_and_open_html(
    html_roberta, "roberta_explanation_opinion105_anchor.html")

# %%
# Acceder a las métricas de precisión y cobertura
print("Presicion:", exp.precision())
print("CoBertura:", exp.coverage())
# Out:
# Presicion: 0.9750982961992136
# CoBertura: 0.0
