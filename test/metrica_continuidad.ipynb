# %%
# miguel BERT lime
from explainability_techniques.anchor import AnchorExplainer
from models.bert_model import load_bert_model, classifySentiment
from utils.utils import load_dataset, save_explanation
import pickle
import torch
from torch import nn
from models.bert_model import load_bert_model, classify_sentiment_proba
from explainability_techniques.lime import LIMEExplainer
import numpy as np
import pandas as pd
import webbrowser
import matplotlib.pyplot as plt
import scipy as sp
import shap
from explainability_techniques.shap import SHAPExplainer
from main import Rutas
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import sys
sys.path.append(
    'D:/Universidad/informatica 4 año/Semestre 1/Precticas 2/PP2_XAI')


shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
# LIME bert
print(Rutas.RUTA_NB_lime_bert_dataset)

dataset = load_dataset(Rutas.RUTA_NB_lime_bert_dataset, sep=";")
# Out:
# ../models/opinion_classification/dataset/hotel_review_tain_5000.csv

# %%
# LIME bert

class ModelSentiment(nn.Module):

    def __init__(self, n_classes):
        super(ModelSentiment, self).__init__()

    def forward(self, input_ids, attention_mask):
        cls_output = self.model(input_ids, attention_mask)
        drop_output = self.drop(cls_output.pooler_output)
        output = self.linear(drop_output)
        return output

# %%
# LIME bert

print(Rutas.RUTA_NB_lime_bert)

bert_model = pickle.load(

    open(Rutas.RUTA_NB_lime_bert, "rb"))

tokenizer = AutoTokenizer.from_pretrained(

    "../models/opinion_classification/Bert_Hotel_max_len/")
# Out:
# ../models/opinion_classification/Bert_Model_Hotel_len_data.pkl

# %%
# LIME bert

explainer_bert = LIMEExplainer(class_names=['negative', 'positive'])

# %%
# LIME bert

instance_bert = dataset['Review'].iloc[0]

# %%
# LIME bert

# Teno que ver despues poruqe con el modelo ultimo de miguel no funciona lime y no he probado con anchor
explanation_bert = explainer_bert.explain_instance(

    instance_bert, classify_sentiment_proba)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 4
#       1 # LIME bert
#       2
#       3 # Teno que ver despues poruqe con el modelo ultimo de miguel no funciona lime y no he probado con anchor
# ----> 4 explanation_bert = explainer_bert.explain_instance(
#       5
#       6     instance_bert, classify_sentiment_proba)
#
# File D:\Universidad/informatica 4 año/Semestre 1/Precticas 2/PP2_XAI\explainability_techniques\lime.py:11, in LIMEExplainer.explain_instance(self, instance, predict_function, labels, num_features, num_samples)
#      10 def explain_instance(self, instance, predict_function, labels=(1,), num_features=10, num_samples=5):
# ---> 11     return self.explainer.explain_instance(
#      12         instance,
#      13         predict_function,
#      14         labels=labels,
#      15         num_features=num_features,
# ...

# %%
# LIME bert

html_bert = explanation_bert.as_html()
save_explanation(html_bert, 'bert_explanation.html')
explainer_bert.save_and_open_html(html_bert, 'bert_explanation.html')

# %%
# SHAP bert
dataset = pd.read_csv(
    "../models/opinion_classification/dataset/hotel_review_tain_5000.csv", sep=";")

# %%
# SHAP bert

# define a prediction function
def f(x):
    # print(x)
    tv = torch.tensor([tokenizer.encode(
        v, padding="max_length", max_length=500, truncation=True) for v in x])
    outputs = bert_model(tv)[0].detach().numpy()
    scores = (np.exp(outputs).T / np.exp(outputs).sum(-1)).T
    val = sp.special.logit(scores[:, 1])  # use one vs rest logit units
    # print(scores[:, 0], " Proba")
    return val

# %%
# SHAP bert

bert_model = AutoModelForSequenceClassification.from_pretrained(
    "../Fine_turned/")


tokenizer = AutoTokenizer.from_pretrained(
    "../models/opinion_classification/Bert_Hotel_max_len/")

# %%
# SHAP bert

review = dataset["Review"].iloc[:15]

# %%
# SHAP bert
# build an explainer using a token masker
explainer = shap.Explainer(f, tokenizer)

# explain the model's predictions on IMDB reviews
shap_values = explainer(review[:3], fixed_context=1, batch_size=10)
# Out:
# We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# PartitionExplainer explainer: 4it [23:15, 465.31s/it]

# %%
# SHAP bert
shap.text_plot(shap_values)
# Out:
#     <br>
#     <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
#     <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
#     </div>
# ...

# %%
# ANCHOR bert

dataset = load_dataset(
    "../models/opinion_classification/dataset/hotel_review_tain_5000.csv", sep=";")

# %%
# ANCHOR bert
class ModelSentiment(nn.Module):

    def __init__(self, n_classes):
        super(ModelSentiment, self).__init__()

    def forward(self, input_ids, attention_mask):
        cls_output = self.model(input_ids, attention_mask)
        drop_output = self.drop(cls_output.pooler_output)
        output = self.linear(drop_output)
        return output

# %%
# ANCHOR bert
bert_model = load_bert_model()
tokenizer = AutoTokenizer.from_pretrained(
    "../models/opinion_classification/Bert_Hotel_max_len/")

# %%
# ANCHOR bert
# Crear el explicador de Anchors
anchor_explainer = AnchorExplainer(class_names=['negative', 'positive'])

# %%
# ANCHOR bert
# Seleccionar una instancia para explicar
instance = dataset['Review'].iloc[0]

# %%
# ANCHOR bert
def predict_classify_sentiment(instance):
    if isinstance(instance, list):
        print("entraaaaaa")
        instance = instance[0]  # Extraer el primer elemento si es una lista
    return classifySentiment(instance)

# %%
# ANCHOR bert
# Explicar la instancia
exp = anchor_explainer.explain_instance(
    instance, predict_classify_sentiment, threshold=0.95)
# Out:
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# entraaaaaa
# ...

# %%
# ANCHOR bert
# Mostrar resultados
print(type(exp))


# anchor_explainer.print_results(exp)


# Guardar y abrir el HTML


anchor_explainer.save_and_open_html(exp.as_html(), "anchor_explanation.html")
# Out:
# <class 'anchor.anchor_explanation.AnchorExplanation'>

# %%
# ANCHOR bert
def calculate_anchor_feature_importance(anchor_explainer, instance):
    """
    Calcula la importancia de las características utilizando el método ANCHOR.

    :param anchor_explainer: Un objeto AnchorText previamente ajustado.
    :param instance: Una instancia (texto) para la cual se desea calcular la importancia.
    :return: Un diccionario con las importancias de las características.
    """
    # Generar una explicación para la instancia 'instance'
    exp = anchor_explainer.explain_instance(
        instance, predict_classify_sentiment, threshold=0.95)

    # Convertir las explicaciones a un diccionario de importancias
    feature_importance = {}
    for feature, importance in exp.as_list():
        feature_importance[feature] = importance

    return feature_importance

# %%
import torch
import tensorflow as tf

print(torch.__version__)
print(tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[54], line 2
#       1 import torch
# ----> 2 import tensorflow as tf
#       4 print(torch.__version__)
#       5 print(tf.__version__)
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# PERTURBACIONES
# Paso 1: Generar Perturbaciones
from metricas_LIME import calculate_lime_feature_importance
from metricas_SHAP import calculate_shap_feature_importance

print(type(dataset))
print(dataset.index)
print(dataset.columns, dataset.shape[1])
print(dataset.dtypes)


def perturbar_instancias(dataset, porcentaje_ruido=0.05):
    dataset_perturbado = dataset.copy()
    for i in range(dataset.shape[0]):
        for j in range(dataset.shape[1]):
            ruido = np.random.uniform(-porcentaje_ruido, porcentaje_ruido)

            alo = ruido * dataset.iloc[i, j]
            dataset_perturbado.iloc[i, j] += ruido * dataset.iloc[i, j]
    return dataset_perturbado


X_test_perturbado = perturbar_instancias(dataset)

X_perturbado = perturbar_instancias(dataset, porcentaje_ruido=0.05)
# #Importancia de las caracteristicas para LORE mediante el arbol
# importances = dt.feature_importances_
# importance_feature_lore = dict(zip(feature_names, importances))

# importances_perturbada = exp_perturbada_lore.dt.feature_importances_
# importance_feature_lore_perturbada = dict(zip(feature_names, importances_perturbada))


def normalizar_importancias(importancias, feature_names):
    return {feature: importancias.get(feature, 0) for feature in feature_names}


def comparar_importancias(importancia_original, importancia_perturbada, es_array=False):
    if es_array:
        # Si es un array, calcula y devuelve la diferencia absoluta media directamente
        return np.abs(importancia_original - importancia_perturbada).mean()
    else:
        # Si es un diccionario, calcula la distancia como antes
        distancia = {}
        for feature in importancia_original:
            distancia[feature] = np.abs(importancia_original.get(
                feature, 0) - importancia_perturbada.get(feature, 0))
        return np.mean(list(distancia.values()))


# Importancia de las características para LIME
# def calculate_lime_feature_importance(lime_explainer, x):
#     explanation = lime_explainer.explain_instance(x, bb_predict_proba)
#     feature_importance = dict(explanation.as_list())
#     return feature_importance
lime_feature_importance = calculate_lime_feature_importance(
    explainer_bert, instance_bert)

# def calculate_shap_feature_importance(shap_explainer, x_instance):
#     shap_values = shap_explainer.shap_values(x_instance)
#     feature_importance = np.mean(np.abs(shap_values), axis=0)
#     return feature_importance


def calcular_continuidad(anchor_explainer, lime_explainer, shap_explainer, x, X_perturbado):
    continuidad_anchor = []
    continuidad_lime = []
    continuidad_shap = []

    for i in range(len(x)):
        # Obtener las importancias originales y perturbadas para cada método
        anchor_orig = calculate_anchor_feature_importance(
            anchor_explainer, x[i])
        anchor_pert = calculate_anchor_feature_importance(
            anchor_explainer, X_perturbado[i])
        lime_orig = calculate_lime_feature_importance(lime_explainer, x[i])
        lime_pert = calculate_lime_feature_importance(
            lime_explainer, X_perturbado[i])
        shap_orig = calculate_shap_feature_importance(shap_explainer, x[i])
        shap_pert = calculate_shap_feature_importance(
            shap_explainer, X_perturbado[i])

        # Convertir a arreglos numpy
        anchor_orig_array = np.array(list(anchor_orig.values()))
        anchor_pert_array = np.array(list(anchor_pert.values()))
        lime_orig_array = np.array(list(lime_orig.values()))
        lime_pert_array = np.array(list(lime_pert.values()))

        # Calcular la continuidad según la nueva fórmula
        continuidad_anchor.append(np.linalg.norm(
            anchor_orig_array - anchor_pert_array, 1) / np.linalg.norm(x[i] - X_perturbado[i], 2))
        continuidad_lime.append(np.linalg.norm(
            lime_orig_array - lime_pert_array, 1) / np.linalg.norm(x[i] - X_perturbado[i], 2))
        continuidad_shap.append(np.linalg.norm(
            shap_orig - shap_pert, 1) / np.linalg.norm(x[i] - X_perturbado[i], 2))

    return continuidad_anchor, continuidad_lime, continuidad_shap


# Función para visualizar continuidades
def visualizar_continuidades_comparativas(continuidades, metodos, titulo):
    plt.figure(figsize=(12, 6))
    colores = ['blue', 'green', 'red']  # Define colores para cada método

    for i, metodo in enumerate(metodos):
        plt.plot(continuidades[i], label=metodo, color=colores[i])

    plt.xlabel('Instancias')
    plt.ylabel('Continuidad')
    plt.title(titulo)
    plt.legend()
    plt.show()


# Llamada a la función y visualización
continuidad_anchor, continuidad_lime, continuidad_shap = calcular_continuidad(
    anchor_explainer, explainer_bert, explainer, dataset, X_perturbado)
visualizar_continuidades_comparativas([continuidad_anchor, continuidad_lime, continuidad_shap], [
                                      "ANCHOR", "LIME", "SHAP"], "Comparación de Continuidad de ANCHOR, LIME y SHAP")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex(start=0, stop=5000, step=1)
# Index(['sentiment', 'Review'], dtype='object') 2
# sentiment     int64
# Review       object
# dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 22
#      18             dataset_perturbado.iloc[i,j] += ruido * dataset.iloc[i,j]
#      19     return dataset_perturbado
# ---> 22 X_test_perturbado = perturbar_instancias(dataset)
#      24 X_perturbado = perturbar_instancias(dataset, porcentaje_ruido=0.05)
#      25 # #Importancia de las caracteristicas para LORE mediante el arbol
#      26 # importances = dt.feature_importances_
#      27 # importance_feature_lore = dict(zip(feature_names, importances))
#      28
#      29 # importances_perturbada = exp_perturbada_lore.dt.feature_importances_
# ...
